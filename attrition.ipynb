# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# prompt: # Create y_df with the Attrition and Department columns

y_df = attrition_df[['Attrition', 'Department']]

# %%
# prompt: # Create a list of at least 10 column names to use as X data
# # Create X_df using your selected columns
# # Show the data types for X_df

# Create a list of at least 10 column names to use as X data
selected_columns = ['Education', 'Age', 'DistanceFromHome', 'JobSatisfaction', 'OverTime', 'StockOptionLevel',
                   'WorkLifeBalance', 'YearsAtCompany', 'YearsSinceLastPromotion', 'NumCompaniesWorked']

# Create X_df using your selected columns
X_df = attrition_df[selected_columns]

# Show the data types for X_df
X_df.dtypes
# Out:
# Education                   int64
# Age                         int64
# DistanceFromHome            int64
# JobSatisfaction             int64
# OverTime                   object
# StockOptionLevel            int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsSinceLastPromotion     int64
# NumCompaniesWorked          int64
# dtype: object

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

# %%
# prompt:  # Convert your X data to numeric data types int64

# Convert your X data to numeric data types int64
for column in X_df.columns:
  if X_df[column].dtype == object:
    X_df[column] = pd.to_numeric(X_df[column], errors='coerce')

X_df = X_df.fillna(0).astype(np.int64)
# Out:
# <ipython-input-6-e1a3aad3eff1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_df[column] = pd.to_numeric(X_df[column], errors='coerce')

# %%
# prompt: # unique_responses = df['column_name'].unique()
# # Print the unique responses
# print(unique_responses)

# unique_responses = X_df['OverTime'].nunique()
# Print the unique responses
X_df.nunique()
# Out:
# Education                   5
# Age                        43
# DistanceFromHome           29
# JobSatisfaction             4
# OverTime                    1
# StockOptionLevel            4
# WorkLifeBalance             4
# YearsAtCompany             37
# YearsSinceLastPromotion    16
# NumCompaniesWorked         10
# dtype: int64

# %%
# prompt: # Create a StandardScaler
# # Fit the StandardScaler to the training data
# # Scale the training and testing data

# Split our preprocessed data into our features and target arrays
y = attrition_df[['Attrition','Department']]
X = X_df

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# prompt: # Create a OneHotEncoder for the Department column
# # Fit the encoder to the training data
# # Create two new variables by applying the encoder
# # to the training and testing data

from sklearn.preprocessing import OneHotEncoder

# Create a OneHotEncoder instance
enc = OneHotEncoder(handle_unknown='ignore')

# Fit the encoder to the Department column in the training data
enc.fit(np.array(y_train['Department']).reshape(-1, 1))

# Create new variables by applying the encoder to the training and testing data
encoded_dept_train = enc.transform(np.array(y_train['Department']).reshape(-1, 1)).toarray()
encoded_dept_test = enc.transform(np.array(y_test['Department']).reshape(-1, 1)).toarray()

encoded_dept_train
# Out:
# array([[0., 0., 1.],
#        [0., 1., 0.],
#        [0., 0., 1.],
#        ...,
#        [0., 1., 0.],
#        [0., 0., 1.],
#        [0., 1., 0.]])

# %%
encoded_dept_train.shape
# Out:
# (1102, 3)

# %%
# Create a OneHotEncoder for the Attrition column
from sklearn.preprocessing import OneHotEncoder

# Create a OneHotEncoder instance
enc = OneHotEncoder(handle_unknown='ignore')

# Fit the encoder to the Department column in the training data
enc.fit(np.array(y_train['Attrition']).reshape(-1, 1))

# Create new variables by applying the encoder to the training and testing data
encoded_attrit_train = enc.transform(np.array(y_train['Attrition']).reshape(-1, 1)).toarray()
encoded_attrit_test = enc.transform(np.array(y_test['Attrition']).reshape(-1, 1)).toarray()

encoded_attrit_train
# Out:
# array([[0., 1.],
#        [1., 0.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [0., 1.]])

# %%
encoded_attrit_train.shape
# Out:
# (1102, 2)

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# prompt: # Find the number of columns in the X training data
number_input_features = len(X_train.columns)
number_input_features
# Out:
# 10

# %%
# prompt: # Create the input layer
input_layer = layers.Input(shape=(number_input_features,))

# Create at least two shared layers
shared_layer_1 = layers.Dense(units=64, activation='relu')(input_layer)
shared_layer_2 = layers.Dense(units=128, activation='relu')(shared_layer_1)

# Create separate output layers
# output_layer = layers.Dense(units=1, activation='sigmoid')(shared_layer_2)

# %%
# prompt: # Create a branch for Department
# # with a hidden layer and an output layer
# # Create the hidden layer
# # Create the output layer

# Create the hidden layer for the Department branch
department_hidden = layers.Dense(units=32, activation='relu')(shared_layer_2)

# Create the output layer for the Department branch
department_output = layers.Dense(units=len(encoded_dept_train[1]), activation='sigmoid', name='department_output')(department_hidden)

# %%
# prompt: # Create a branch for Attrition
# # with a hidden layer and an output layer
# # Create the hidden layer
# # Create the output layer

# Create the hidden layer for the Attrition branch
attrition_hidden = layers.Dense(units=32, activation='relu')(shared_layer_2)

# Create the output layer for the Attrition branch
attrition_output = layers.Dense(units=len(encoded_attrit_train[1]), activation='sigmoid', name='attrition_output')(attrition_hidden)

# %%
# prompt: # Create the model
# # Compile the model
# # Summarize the model

# Create the model
model = Model(inputs=input_layer, outputs=[department_output, attrition_output])

# Compile the model
model.compile(loss=['categorical_crossentropy', 'binary_crossentropy'], optimizer='adam', metrics=['accuracy', 'accuracy'])

# Print a summary of the model
model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3             │ (None, 10)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 64)             │            704 │ input_layer_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 128)            │          8,320 │ dense_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_24 (Dense)          │ (None, 32)             │          4,128 │ dense_15[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_25 (Dense)          │ (None, 32)             │          4,128 │ dense_15[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ department_output (Dense) │ (None, 3)              │             99 │ dense_24[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attrition_output (Dense)  │ (None, 2)              │             66 │ dense_25[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 17,445 (68.14 KB)
#  Trainable params: 17,445 (68.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# prompt: # Train the model using the preprocessed data

# Train the model
fit_model = model.fit(X_train_scaled, [encoded_dept_train, encoded_attrit_train], epochs=100)
# Out:
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - attrition_output_accuracy: 0.7703 - department_output_accuracy: 0.5450 - loss: 1.5918
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8296 - department_output_accuracy: 0.6737 - loss: 1.2046
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8495 - department_output_accuracy: 0.6471 - loss: 1.1982
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8298 - department_output_accuracy: 0.6654 - loss: 1.1506
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8163 - department_output_accuracy: 0.6842 - loss: 1.1432
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8239 - department_output_accuracy: 0.6728 - loss: 1.1265
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8469 - department_output_accuracy: 0.6539 - loss: 1.1296
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8543 - department_output_accuracy: 0.6753 - loss: 1.0837
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8445 - department_output_accuracy: 0.6666 - loss: 1.1188
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8328 - department_output_accuracy: 0.6807 - loss: 1.1184
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8577 - department_output_accuracy: 0.6768 - loss: 1.0795
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8495 - department_output_accuracy: 0.6384 - loss: 1.1409
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8596 - department_output_accuracy: 0.6773 - loss: 1.0632
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8680 - department_output_accuracy: 0.7004 - loss: 1.0108
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8466 - department_output_accuracy: 0.6971 - loss: 1.0330
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8628 - department_output_accuracy: 0.6797 - loss: 0.9937
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8518 - department_output_accuracy: 0.7050 - loss: 1.0041
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8656 - department_output_accuracy: 0.7119 - loss: 0.9547
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8658 - department_output_accuracy: 0.7253 - loss: 0.9643
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.